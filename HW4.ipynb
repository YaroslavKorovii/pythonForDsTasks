# %%
numbers = []
for i in range(1,8):
    numbers.append(i)

print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
names = ["Олег", "Анна", "Іван", "Марія"]
for name in names:
    print(f"Привіт, {name}!")
# Out:
# Привіт, Олег!
# Привіт, Анна!
# Привіт, Іван!
# Привіт, Марія!

# %%
grades = [85, 92, 78, 95, 88]
for index, grade in enumerate(grades):
    print(f"Студент {index + 1}: {grade} балів")
# Out:
# Студент 1: 85 балів
# Студент 2: 92 балів
# Студент 3: 78 балів
# Студент 4: 95 балів
# Студент 5: 88 балів

# %%
total = 0
for n in range(1,21):
    if n % 2 == 0:
        total += n
        
print(total)
# Out:
# 110
